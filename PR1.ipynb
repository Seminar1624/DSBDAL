# %%
#impoet libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
#load dataset
data = pd.read_csv('nba.csv')
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data = pd.read_csv('nba.csv')
print(data.to_string(index=False))
# Out:
#                     Name                   Team  Number Position  Age Height  Weight               College     Salary
#            Avery Bradley         Boston Celtics     0.0       PG 25.0    6-2   180.0                 Texas  7730337.0
#              Jae Crowder         Boston Celtics    99.0       SF 25.0    6-6   235.0             Marquette  6796117.0
#             John Holland         Boston Celtics    30.0       SG 27.0    6-5   205.0     Boston University        NaN
#              R.J. Hunter         Boston Celtics    28.0       SG 22.0    6-5   185.0         Georgia State  1148640.0
#            Jonas Jerebko         Boston Celtics     8.0       PF 29.0   6-10   231.0                   NaN  5000000.0
#             Amir Johnson         Boston Celtics    90.0       PF 29.0    6-9   240.0                   NaN 12000000.0
#            Jordan Mickey         Boston Celtics    55.0       PF 21.0    6-8   235.0                   LSU  1170960.0
# ...

# %%
data.shape
# Out:
# (458, 9)

# %%
data.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
#Value count of Type field
data.Type.value_counts()
# Out:
# Type
# h    4470
# u    1761
# t     578
# Name: count, dtype: int64

# %%
#print 2 values
data.head(2)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
#null count
data.isnull().any().count()
# Out:
# 9

# %%
#sum of null
data.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
import seaborn as sns
missing_values  = data.isnull().sum().sort_values(ascending = False)
missing_df = pd.concat([missing_values], axis = 1, keys = ['Total'])
f, ax = plt.subplots(figsize = (12,6))
sns.barplot(x = missing_values.index, y = missing_values)
plt.xticks(rotation = 90)
plt.title('Missing Values in Features')
plt.ylabel('Total missing values')
plt.show()

# %%
#Apply unique code and convert in categorical value
cat_columns = data.select_dtypes(['category']).columns
data[cat_columns] = data[cat_columns].apply(lambda x: x.cat.codes)

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data=data.dropna()

# %%
data.shape
# Out:
# (364, 9)

# %%
data.sample(9)
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 0       Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2
# 317   Lamar Patterson           Atlanta Hawks    13.0       SG  24.0    6-5
# 215       Tyler Ennis         Milwaukee Bucks    11.0       PG  21.0    6-3
# 308        David West       San Antonio Spurs    30.0       PF  35.0    6-9
# 416      Josh Huestis   Oklahoma City Thunder    34.0       SF  24.0    6-7
# 412      Steven Adams   Oklahoma City Thunder    12.0        C  22.0    7-0
# 24   Chris McCullough           Brooklyn Nets     1.0       PF  21.0   6-11
# 406   Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 432  Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0    6-9
#
#      Weight     College     Salary
# 0     180.0       Texas  7730337.0
# 317   225.0  Pittsburgh   525093.0
# 215   194.0    Syracuse  1662360.0
# 308   250.0      Xavier  1499187.0
# ...

# %%
#index
data.index
# Out:
# Index([  0,   1,   3,   6,   7,   8,   9,  10,  11,  12,
#        ...
#        442, 443, 444, 446, 448, 449, 451, 452, 453, 456],
#       dtype='int64', length=364)

# %%
#Transpose
data.T
# Out:
#                      0               1               3               6    \
# Name       Avery Bradley     Jae Crowder     R.J. Hunter   Jordan Mickey
# Team      Boston Celtics  Boston Celtics  Boston Celtics  Boston Celtics
# Number               0.0            99.0            28.0            55.0
# Position              PG              SF              SG              PF
# Age                 25.0            25.0            22.0            21.0
# Height               6-2             6-6             6-5             6-8
# Weight             180.0           235.0           185.0           235.0
# College            Texas       Marquette   Georgia State             LSU
# Salary         7730337.0       6796117.0       1148640.0       1170960.0
#
#                      7               8               9                10   \
# Name        Kelly Olynyk    Terry Rozier    Marcus Smart  Jared Sullinger
# Team      Boston Celtics  Boston Celtics  Boston Celtics   Boston Celtics
# ...

# %%
#sort
data.sort_index(axis=1, ascending=False)
# Out:
#      Weight            Team     Salary Position  Number           Name Height  \
# 0     180.0  Boston Celtics  7730337.0       PG     0.0  Avery Bradley    6-2
# 1     235.0  Boston Celtics  6796117.0       SF    99.0    Jae Crowder    6-6
# 3     185.0  Boston Celtics  1148640.0       SG    28.0    R.J. Hunter    6-5
# 6     235.0  Boston Celtics  1170960.0       PF    55.0  Jordan Mickey    6-8
# 7     238.0  Boston Celtics  2165160.0        C    41.0   Kelly Olynyk    7-0
# ..      ...             ...        ...      ...     ...            ...    ...
# 449   206.0       Utah Jazz  1348440.0       SG     5.0    Rodney Hood    6-8
# 451   206.0       Utah Jazz   981348.0       SF    23.0  Chris Johnson    6-6
# 452   234.0       Utah Jazz  2239800.0       PF    41.0     Trey Lyles   6-10
# 453   203.0       Utah Jazz  2433333.0       PG     8.0   Shelvin Mack    6-3
# 456   231.0       Utah Jazz   947276.0        C    24.0    Jeff Withey    7-0
#
#            College   Age
# ...

# %%
data["Position"]
# Out:
# 0      PG
# 1      SF
# 3      SG
# 6      PF
# 7       C
#        ..
# 449    SG
# 451    SF
# 452    PF
# 453    PG
# 456     C
# Name: Position, Length: 364, dtype: object

# %%
#filter according to age
filtered_df = data[data['Age'] > 20]
print(filtered_df)
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..              ...             ...     ...      ...   ...    ...     ...
# 448  Gordon Hayward       Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451   Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 453    Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456     Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
data["Weight"]>150
# Out:
# 0      True
# 1      True
# 3      True
# 6      True
# 7      True
#        ...
# 449    True
# 451    True
# 452    True
# 453    True
# 456    True
# Name: Weight, Length: 364, dtype: bool

# %%
missing_data=data.isnull()

# %%
print(missing_data)
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 3    False  False   False     False  False   False   False    False   False
# 6    False  False   False     False  False   False   False    False   False
# 7    False  False   False     False  False   False   False    False   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 449  False  False   False     False  False   False   False    False   False
# 451  False  False   False     False  False   False   False    False   False
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 456  False  False   False     False  False   False   False    False   False
#
# [364 rows x 9 columns]

# %%
data1=data

# %%
data1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %%
#fill null value with 1
data1.fillna(1)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
data[data["Team"].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
#fill null age to median value
data['Age'].fillna(data['Age'].median(),inplace=True)
data.head()
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
#display with specific field
data[data["Team"]=="Boston Celtics"]
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 12      Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
# 14     Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   253.0
#
# ...

# %%
output = data.iat[2, 1]

print(output)
# Out:
# Boston Celtics

# %%
output = data.iloc[2, 1]

print(output)
# Out:
# Boston Celtics

# %%
data = pd.read_csv('nba.csv')
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
#describe datatype
data.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
#convert datatype to object 
data1=data.astype('object').dtypes

# %%
data1.dtypes
# Out:
# dtype('O')

# %%
data1.describe()
# Out:
# count          9
# unique         1
# top       object
# freq           9
# dtype: object

# %%
print(data1.dtypes)
# Out:
# object

# %%
data1.head(10)
# Out:
# Name        object
# Team        object
# Number      object
# Position    object
# Age         object
# Height      object
# Weight      object
# College     object
# Salary      object
# dtype: object

# %%
#convert particular datatype
data['Number'] = data['Number'].astype('float32')

# %%
data.dtypes
# Out:
# Name         object
# Team         object
# Number      float32
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
#convert to categorical data
s = pd.Series(['Position'], dtype="category")
print('Series with Categorical Data:\n', s)
# Out:
# Series with Categorical Data:
#  0    Position
# dtype: category
# Categories (1, object): ['Position']

# %%
data['Position'] = data['Position'].astype('category')

# Create a new column 'Position_Code' that maps the positions to integer codes
data['Position_Code'] = data['Position'].cat.codes

# Display the updated DataFrame
print(data[['Name', 'Position', 'Position_Code']])
# Out:
#               Name Position  Position_Code
# 0    Avery Bradley       PG              2
# 1      Jae Crowder       SF              3
# 2     John Holland       SG              4
# 3      R.J. Hunter       SG              4
# 4    Jonas Jerebko       PF              1
# ..             ...      ...            ...
# 453   Shelvin Mack       PG              2
# 454      Raul Neto       PG              2
# 455   Tibor Pleiss        C              0
# 456    Jeff Withey        C              0
# 457            NaN      NaN             -1
#
# [458 rows x 3 columns]

# %%
#Unique
arr=data['Age'].unique()
print(arr)
# Out:
# [25. 27. 22. 29. 21. 24. 20. 26. 28. 32. 23. 30. 33. 34. 37. 36. 31. 38.
#  39. 19. 35. 40. nan]

# %%
#value_counts
data.value_counts()
# Out:
# Name                    Team                   Number  Position  Age   Height  Weight  College         Salary      Position_Code
# Aaron Brooks            Chicago Bulls          0.0     PG        31.0  6-0     161.0   Oregon          2250000.0   2                1
# Mike Muscala            Atlanta Hawks          31.0    PF        24.0  6-11    240.0   Bucknell        947276.0    1                1
# Mike Dunleavy           Chicago Bulls          34.0    SG        35.0  6-9     230.0   Duke            4500000.0   4                1
# Mike Conley             Memphis Grizzlies      11.0    PG        28.0  6-1     175.0   Ohio State      9588426.0   2                1
# Michael Kidd-Gilchrist  Charlotte Hornets      14.0    SF        22.0  6-7     232.0   Kentucky        6331404.0   3                1
#                                                                                                                                    ..
# ...

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 20.0    19
# 21.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: count, dtype: int64

# %%
#mode function
data.mode()
# Out:
#                 Name                  Team  Number Position   Age Height  \
# 0       Aaron Brooks  New Orleans Pelicans     5.0       SG  24.0    6-9
# 1       Aaron Gordon                   NaN     NaN      NaN   NaN    NaN
# 2     Aaron Harrison                   NaN     NaN      NaN   NaN    NaN
# 3      Adreian Payne                   NaN     NaN      NaN   NaN    NaN
# 4         Al Horford                   NaN     NaN      NaN   NaN    NaN
# ..               ...                   ...     ...      ...   ...    ...
# 452  Wilson Chandler                   NaN     NaN      NaN   NaN    NaN
# 453   Xavier Munford                   NaN     NaN      NaN   NaN    NaN
# 454      Zach LaVine                   NaN     NaN      NaN   NaN    NaN
# 455    Zach Randolph                   NaN     NaN      NaN   NaN    NaN
# 456    Zaza Pachulia                   NaN     NaN      NaN   NaN    NaN
#
#      Weight   College    Salary  Position_Code
# ...

# %%
#most frequent value
data.value_counts().idxmax()
# Out:
# ('Aaron Brooks',
#  'Chicago Bulls',
#  0.0,
#  'PG',
#  31.0,
#  '6-0',
#  161.0,
#  'Oregon',
#  2250000.0,
#  2)

# %%
#min frequent value
data.value_counts().idxmin()
# Out:
# ('Aaron Brooks',
#  'Chicago Bulls',
#  0.0,
#  'PG',
#  31.0,
#  '6-0',
#  161.0,
#  'Oregon',
#  2250000.0,
#  2)
